# %%
# !pip install --quiet guitarsounds

# %%
from guitarsounds import Sound, SoundPack
mysound = Sound('Wood_E1.wav')
#mysound = Sound('sg.wav')

# %%
mysound.signal.listen()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mysounds = SoundPack(mysound)

# %%
mysounds.plot('signal')
# Out:
# <AxesSubplot:title={'center':'signal plot'}, xlabel='time (s)', ylabel='amplitude [-1, 1]'>

# %%
mysounds.plot('fft')
# Out:
# <AxesSubplot:title={'center':'fft plot'}, xlabel='frequency (Hz)', ylabel='amplitude (normalized)'>
